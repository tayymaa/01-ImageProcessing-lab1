# %%
a= 3
b= 9e3
c= -39j

print(type(a))
print(type(b))
print(type(c))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'complex'>

# %%
print("Real part:", type( c.real))
print("Imaginary part:", type (c.imag))
# Out:
# Real part: <class 'float'>
# Imaginary part: <class 'float'>

# %%
x= float(a)
print(type(x))
print(x)
# Out:
# <class 'float'>
# 3.0

# %%
y=complex(b)
print(type(y))
print(y)
# Out:
# <class 'complex'>
# (9000+0j)

# %%
z=float(c)
print(type(z))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 z=float(c)
#       2 print(type(z))
#
# TypeError: float() argument must be a string or a real number, not 'complex'

# %%
x1 = complex(a)
print(type(x1))
print(x1)
# Out:
# <class 'complex'>
# (3+0j)

# %% [raw]
# import random
#
# r = random.randint(14,24)
# print(r)

# %%
p = "strive"
print(p[-4:])
print(p[2:6])
# Out:
# rive
# rive
